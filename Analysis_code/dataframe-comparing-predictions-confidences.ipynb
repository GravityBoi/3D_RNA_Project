# %%
import shutil
import os

# Copy USalign to working directory and make it executable
shutil.copy2("/kaggle/input/usalign/USalign", "/kaggle/working/USalign")
os.chmod("/kaggle/working/USalign", 0o755)

print("USalign copied to /kaggle/working/ and made executable")
# Out:
# USalign copied to /kaggle/working/ and made executable

# %%
import os
import re
import numpy as np
import pandas as pd

def parse_tmscore_output(output):
    tm_score_match = re.findall(r'TM-score=\s+([\d.]+)', output)[1]
    return float(tm_score_match)

def write_target_line(
    atom_name, atom_serial, residue_name, chain_id, residue_num,
    x_coord, y_coord, z_coord, occupancy=1.0, b_factor=0.0, atom_type='P'
) -> str:
    return (
        f'ATOM  {atom_serial:>5d}  {atom_name:<5s} {residue_name:<3s} '
        f'{residue_num:>3d}    {x_coord:>8.3f}{y_coord:>8.3f}'
        f'{z_coord:>8.3f}{occupancy:>6.2f}{b_factor:>6.2f}           {atom_type}\n'
    )

def write2pdb(df: pd.DataFrame, xyz_id: int, target_path: str) -> int:
    resolved_cnt = 0
    with open(target_path, 'w') as f:
        for _, row in df.iterrows():
            x = row[f'x_{xyz_id}']; y = row[f'y_{xyz_id}']; z = row[f'z_{xyz_id}']
            if x > -1e17 and y > -1e17 and z > -1e17:
                resolved_cnt += 1
                f.write(write_target_line(
                    atom_name="C1'", atom_serial=int(row['resid']),
                    residue_name=row['resname'], chain_id='0',
                    residue_num=int(row['resid']),
                    x_coord=x, y_coord=y, z_coord=z, atom_type='C'
                ))
    return resolved_cnt

def get_base_target_id(long_id):
    return "_".join(str(long_id).split("_")[:-1])

def score_and_compare_models(solution: pd.DataFrame, submission1: pd.DataFrame, 
                           submission2: pd.DataFrame, submission3: pd.DataFrame,
                           model_names: list = None):
    """
    Compare 3 models and select best prediction for each target
    
    Args:
        solution: Ground truth dataframe
        submission1, submission2, submission3: Model prediction dataframes
        model_names: List of model names (default: ['Model1', 'Model2', 'Model3'])
    
    Returns:
        results_df: DataFrame with best predictions and metadata
        mean_tm: Overall mean TM score
    """
    if model_names is None:
        model_names = ['Model1', 'Model2', 'Model3']
    
    submissions = [submission1, submission2, submission3]
    
    # Add target_id to all dataframes
    solution['target_id'] = solution['ID'].apply(get_base_target_id)
    for sub in submissions:
        sub['target_id'] = sub['ID'].apply(get_base_target_id)
    
    native_idxs = sorted(int(c.split('_')[1])
                         for c in solution.columns if c.startswith('x_'))
    
    usalign = "/kaggle/working/USalign"
    
    # Find common targets across all submissions
    common_targets = set(solution['target_id'].unique())
    for sub in submissions:
        common_targets &= set(sub['target_id'].unique())
    common_targets = sorted(list(common_targets))
    
    print(f"Scoring {len(common_targets)} common targets across {len(submissions)} models...")
    
    results_list = []
    all_best_tm_scores = []
    
    for tid in common_targets:
        grp_nat = solution[solution['target_id'] == tid]
        grp_preds = [sub[sub['target_id'] == tid] for sub in submissions]
        
        best_overall_tm = 0.0
        best_model_idx = 0
        best_pred_idx = 1
        best_model_scores = []
        
        # Test all models and all predictions for this target
        for model_idx, grp_pred in enumerate(grp_preds):
            model_best_scores = []
            
            for pred_cnt in range(1, 6):
                best_for_this_pred = 0.0
                for nat_cnt in native_idxs:
                    n_nat = write2pdb(grp_nat, nat_cnt, 'native.pdb')
                    n_pred = write2pdb(grp_pred, pred_cnt, 'predicted.pdb')
                    if n_nat > 0 and n_pred > 0:
                        out = os.popen(
                            f'{usalign} predicted.pdb native.pdb -atom " C1\'"'
                        ).read()
                        best_for_this_pred = max(best_for_this_pred,
                                               parse_tmscore_output(out))
                model_best_scores.append(best_for_this_pred)
                
                # Check if this is the best overall prediction
                if best_for_this_pred > best_overall_tm:
                    best_overall_tm = best_for_this_pred
                    best_model_idx = model_idx
                    best_pred_idx = pred_cnt
            
            best_model_scores.append(model_best_scores)
        
        # Get the winning prediction data
        winning_submission = grp_preds[best_model_idx]
        winning_row = winning_submission.iloc[0]  # Get first row for metadata
        
        # Extract sequence info
        sequence = winning_row.get('sequence', '')
        sequence_length = len(sequence) if sequence else len(grp_nat)
        
        # Store results
        result_entry = {
            'ID': tid,
            'sequence': sequence,
            'sequence_length': sequence_length,
            'chosen_model': model_names[best_model_idx],
            'chosen_prediction': best_pred_idx,
            'tm_score': best_overall_tm
        }
        
        # Add the winning coordinates
        for coord in ['x', 'y', 'z']:
            result_entry[f'{coord}_{best_pred_idx}'] = winning_submission[f'{coord}_{best_pred_idx}'].tolist()
        
        results_list.append(result_entry)
        all_best_tm_scores.append(best_overall_tm)
        
        # Print detailed results
        print(f"{tid}:")
        for i, model_scores in enumerate(best_model_scores):
            print(f"  {model_names[i]}: TM-scores = {[f'{s:.4f}' for s in model_scores]}, best = {max(model_scores):.4f}")
        print(f"  Winner: {model_names[best_model_idx]} (prediction {best_pred_idx}) with TM-score = {best_overall_tm:.4f}")
        print()
    
    # Create results dataframe
    results_df = pd.DataFrame(results_list)
    
    # Calculate mean TM score
    mean_tm = np.mean(all_best_tm_scores) if all_best_tm_scores else 0.0
    
    print(f"Overall Mean TM-score: {mean_tm:.4f}")
    
    return results_df, mean_tm

# Example usage:
# Load your data
solution = pd.read_csv("/kaggle/input/validation-labels-clean-csv/validation_labels_clean.csv")
submission1 = pd.read_csv("/kaggle/input/predictions/drfold2_submission_with_confidence.csv") 
submission2 = pd.read_csv("/kaggle/input/predictions/protenix_submission_with_confidence.csv")    
submission3 = pd.read_csv("/kaggle/input/predictions/ribonanzanet2_submission_with_confidence.csv") 

# Run comparison with custom model names
model_names = ['DrFold2', 'Protenix', 'Ribonanzanet2']
results_df, mean_tm = score_and_compare_models(
    solution, submission1, submission2, submission3, model_names
)

# Save results
results_df.to_csv("/kaggle/working/best_predictions_comparison.csv", index=False)
print(f"Results saved to best_predictions_comparison.csv")
print(f"Final mean TM-score across all best predictions: {mean_tm:.4f}")
# Out:
# Scoring 94 common targets across 3 models...
# 8K85_A:
#   DrFold2: TM-scores = ['0.1928', '0.1353', '0.1789', '0.1151', '0.1648'], best = 0.1928
#   Protenix: TM-scores = ['0.2433', '0.2315', '0.2004', '0.2158', '0.2557'], best = 0.2557
#   Ribonanzanet2: TM-scores = ['0.2595', '0.2500', '0.2671', '0.2666', '0.2631'], best = 0.2671
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.2671
#
# 8KEB_A:
#   DrFold2: TM-scores = ['0.5013', '0.4555', '0.5033', '0.5064', '0.4871'], best = 0.5064
#   Protenix: TM-scores = ['0.5655', '0.6077', '0.5995', '0.6291', '0.5555'], best = 0.6291
#   Ribonanzanet2: TM-scores = ['0.1686', '0.2007', '0.1595', '0.4732', '0.4652'], best = 0.4732
#   Winner: Protenix (prediction 4) with TM-score = 0.6291
#
# 8KHH_A:
#   DrFold2: TM-scores = ['0.5209', '0.4610', '0.4841', '0.5290', '0.4848'], best = 0.5290
#   Protenix: TM-scores = ['0.6210', '0.6174', '0.5512', '0.6226', '0.5862'], best = 0.6226
#   Ribonanzanet2: TM-scores = ['0.4789', '0.1586', '0.1694', '0.1653', '0.4767'], best = 0.4789
#   Winner: Protenix (prediction 4) with TM-score = 0.6226
#
# 8QHU_3:
#   DrFold2: TM-scores = ['0.6702', '0.6919', '0.6922', '0.6469', '0.6514'], best = 0.6922
#   Protenix: TM-scores = ['0.2852', '0.2541', '0.2570', '0.2932', '0.2276'], best = 0.2932
#   Ribonanzanet2: TM-scores = ['0.2321', '0.2274', '0.2251', '0.8221', '0.2258'], best = 0.8221
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.8221
#
# 8QHU_4:
#   DrFold2: TM-scores = ['0.7155', '0.8112', '0.8014', '0.8078', '0.7778'], best = 0.8112
#   Protenix: TM-scores = ['0.3518', '0.3662', '0.3703', '0.3046', '0.3888'], best = 0.3888
#   Ribonanzanet2: TM-scores = ['0.9301', '0.8698', '0.8616', '0.9278', '0.9388'], best = 0.9388
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.9388
#
# 8QHU_5:
#   DrFold2: TM-scores = ['0.5175', '0.3197', '0.5293', '0.2959', '0.4962'], best = 0.5293
#   Protenix: TM-scores = ['0.1969', '0.2486', '0.3057', '0.2074', '0.2474'], best = 0.3057
#   Ribonanzanet2: TM-scores = ['0.2340', '0.2403', '0.2461', '0.6104', '0.5778'], best = 0.6104
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.6104
#
# 8QHU_7:
#   DrFold2: TM-scores = ['0.7519', '0.7655', '0.7603', '0.7735', '0.7814'], best = 0.7814
#   Protenix: TM-scores = ['0.1763', '0.1774', '0.2236', '0.1939', '0.1931'], best = 0.2236
#   Ribonanzanet2: TM-scores = ['0.2278', '0.9224', '0.2317', '0.9196', '0.9002'], best = 0.9224
#   Winner: Ribonanzanet2 (prediction 2) with TM-score = 0.9224
#
# 8QHU_S4:
#   DrFold2: TM-scores = ['0.4631', '0.4559', '0.4682', '0.4721', '0.4621'], best = 0.4721
#   Protenix: TM-scores = ['0.7038', '0.6696', '0.7016', '0.7069', '0.6940'], best = 0.7069
#   Ribonanzanet2: TM-scores = ['0.2051', '0.7057', '0.1898', '0.7430', '0.6639'], best = 0.7430
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.7430
#
# 8R7N_A:
#   DrFold2: TM-scores = ['0.2113', '0.2282', '0.1784', '0.2532', '0.2538'], best = 0.2538
#   Protenix: TM-scores = ['0.2515', '0.2643', '0.2098', '0.2288', '0.2249'], best = 0.2643
#   Ribonanzanet2: TM-scores = ['0.1472', '0.3037', '0.1535', '0.3029', '0.1276'], best = 0.3037
#   Winner: Ribonanzanet2 (prediction 2) with TM-score = 0.3037
#
# 8RRI_Ax:
#   DrFold2: TM-scores = ['0.4815', '0.4824', '0.4933', '0.4967', '0.5090'], best = 0.5090
#   Protenix: TM-scores = ['0.4690', '0.5335', '0.5221', '0.5051', '0.5081'], best = 0.5335
#   Ribonanzanet2: TM-scores = ['0.6829', '0.6905', '0.6852', '0.2043', '0.6911'], best = 0.6911
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.6911
#
# 8RWG_C:
#   DrFold2: TM-scores = ['0.7108', '0.7117', '0.7158', '0.7199', '0.7213'], best = 0.7213
#   Protenix: TM-scores = ['0.7419', '0.7268', '0.6601', '0.6816', '0.6541'], best = 0.7419
#   Ribonanzanet2: TM-scores = ['0.9143', '0.2403', '0.2417', '0.9116', '0.2390'], best = 0.9143
#   Winner: Ribonanzanet2 (prediction 1) with TM-score = 0.9143
#
# 8SYK_B:
#   DrFold2: TM-scores = ['0.2286', '0.2233', '0.2215', '0.2264', '0.2999'], best = 0.2999
#   Protenix: TM-scores = ['0.2465', '0.3146', '0.2642', '0.2738', '0.2942'], best = 0.3146
#   Ribonanzanet2: TM-scores = ['0.3541', '0.2593', '0.3517', '0.3621', '0.2811'], best = 0.3621
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.3621
#
# 8SYK_C:
#   DrFold2: TM-scores = ['0.2188', '0.2130', '0.2077', '0.2379', '0.2986'], best = 0.2986
#   Protenix: TM-scores = ['0.3010', '0.2386', '0.3023', '0.2576', '0.3748'], best = 0.3748
#   Ribonanzanet2: TM-scores = ['0.2721', '0.3342', '0.3485', '0.2497', '0.2698'], best = 0.3485
#   Winner: Protenix (prediction 5) with TM-score = 0.3748
#
# 8T5O_A:
#   DrFold2: TM-scores = ['0.2879', '0.3024', '0.3378', '0.2888', '0.3130'], best = 0.3378
#   Protenix: TM-scores = ['0.1885', '0.2038', '0.3122', '0.2806', '0.2321'], best = 0.3122
#   Ribonanzanet2: TM-scores = ['0.2203', '0.1807', '0.2027', '0.1921', '0.2828'], best = 0.2828
#   Winner: DrFold2 (prediction 3) with TM-score = 0.3378
#
# 8VK7_B:
#   DrFold2: TM-scores = ['0.6900', '0.6766', '0.6684', '0.7037', '0.6955'], best = 0.7037
#   Protenix: TM-scores = ['0.5153', '0.5023', '0.5669', '0.5032', '0.5582'], best = 0.5669
#   Ribonanzanet2: TM-scores = ['0.5960', '0.2067', '0.5274', '0.2107', '0.2027'], best = 0.5960
#   Winner: DrFold2 (prediction 4) with TM-score = 0.7037
#
# 8VXZ_C:
#   DrFold2: TM-scores = ['0.1525', '0.1610', '0.1681', '0.1924', '0.1740'], best = 0.1924
#   Protenix: TM-scores = ['0.4436', '0.5038', '0.4632', '0.4256', '0.4189'], best = 0.5038
#   Ribonanzanet2: TM-scores = ['0.6528', '0.6507', '0.6605', '0.6413', '0.6623'], best = 0.6623
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.6623
#
# 8VZ6_S:
#   DrFold2: TM-scores = ['0.1861', '0.2049', '0.1917', '0.1928', '0.1831'], best = 0.2049
#   Protenix: TM-scores = ['0.3403', '0.2816', '0.3113', '0.3235', '0.3612'], best = 0.3612
#   Ribonanzanet2: TM-scores = ['0.2022', '0.2591', '0.2180', '0.2455', '0.1181'], best = 0.2591
#   Winner: Protenix (prediction 5) with TM-score = 0.3612
#
# 8WF8_B:
#   DrFold2: TM-scores = ['0.1846', '0.1921', '0.1693', '0.2013', '0.1733'], best = 0.2013
#   Protenix: TM-scores = ['0.2516', '0.2666', '0.2430', '0.2271', '0.2708'], best = 0.2708
#   Ribonanzanet2: TM-scores = ['0.1137', '0.0975', '0.1087', '0.1170', '0.0795'], best = 0.1170
#   Winner: Protenix (prediction 5) with TM-score = 0.2708
#
# 8WF9_B:
#   DrFold2: TM-scores = ['0.1857', '0.2652', '0.2087', '0.2147', '0.2189'], best = 0.2652
#   Protenix: TM-scores = ['0.2292', '0.2377', '0.2535', '0.1988', '0.2955'], best = 0.2955
#   Ribonanzanet2: TM-scores = ['0.2100', '0.1598', '0.1262', '0.1950', '0.1090'], best = 0.2100
#   Winner: Protenix (prediction 5) with TM-score = 0.2955
#
# 8WFA_B:
#   DrFold2: TM-scores = ['0.2408', '0.2411', '0.2375', '0.2135', '0.1984'], best = 0.2411
#   Protenix: TM-scores = ['0.2779', '0.2163', '0.2551', '0.2518', '0.2774'], best = 0.2779
#   Ribonanzanet2: TM-scores = ['0.1022', '0.1240', '0.1461', '0.1295', '0.1407'], best = 0.1461
#   Winner: Protenix (prediction 1) with TM-score = 0.2779
#
# 8WFB_B:
#   DrFold2: TM-scores = ['0.1988', '0.2408', '0.2090', '0.1838', '0.2047'], best = 0.2408
#   Protenix: TM-scores = ['0.2522', '0.1998', '0.2487', '0.2369', '0.2340'], best = 0.2522
#   Ribonanzanet2: TM-scores = ['0.1381', '0.1071', '0.1646', '0.1511', '0.1925'], best = 0.1925
#   Winner: Protenix (prediction 1) with TM-score = 0.2522
#
# 8XTP_A:
#   DrFold2: TM-scores = ['0.2151', '0.2248', '0.2703', '0.2696', '0.2508'], best = 0.2703
#   Protenix: TM-scores = ['0.2760', '0.2952', '0.2409', '0.2618', '0.2462'], best = 0.2952
#   Ribonanzanet2: TM-scores = ['0.2600', '0.2831', '0.2576', '0.2820', '0.2702'], best = 0.2831
#   Winner: Protenix (prediction 2) with TM-score = 0.2952
#
# 8XTP_B:
#   DrFold2: TM-scores = ['0.1772', '0.1517', '0.1542', '0.1789', '0.1985'], best = 0.1985
#   Protenix: TM-scores = ['0.2110', '0.1996', '0.2270', '0.2656', '0.2419'], best = 0.2656
#   Ribonanzanet2: TM-scores = ['0.1433', '0.1628', '0.1671', '0.2003', '0.1419'], best = 0.2003
#   Winner: Protenix (prediction 4) with TM-score = 0.2656
#
# 8XTR_A:
#   DrFold2: TM-scores = ['0.2140', '0.2333', '0.2483', '0.2292', '0.2114'], best = 0.2483
#   Protenix: TM-scores = ['0.2100', '0.2307', '0.1989', '0.2160', '0.2147'], best = 0.2307
#   Ribonanzanet2: TM-scores = ['0.2150', '0.1970', '0.2350', '0.2392', '0.2360'], best = 0.2392
#   Winner: DrFold2 (prediction 3) with TM-score = 0.2483
#
# 8Y9L_B:
#   DrFold2: TM-scores = ['0.2436', '0.2602', '0.2329', '0.2442', '0.2546'], best = 0.2602
#   Protenix: TM-scores = ['0.4418', '0.4245', '0.4446', '0.4488', '0.4062'], best = 0.4488
#   Ribonanzanet2: TM-scores = ['0.4645', '0.4594', '0.4703', '0.1305', '0.1296'], best = 0.4703
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.4703
#
# 8Y9M_B:
#   DrFold2: TM-scores = ['0.2398', '0.2464', '0.2458', '0.2514', '0.2412'], best = 0.2514
#   Protenix: TM-scores = ['0.4053', '0.3976', '0.4155', '0.4030', '0.4110'], best = 0.4155
#   Ribonanzanet2: TM-scores = ['0.3982', '0.3962', '0.1356', '0.3943', '0.3838'], best = 0.3982
#   Winner: Protenix (prediction 3) with TM-score = 0.4155
#
# 8Y9N_B:
#   DrFold2: TM-scores = ['0.2380', '0.2542', '0.2418', '0.2446', '0.2532'], best = 0.2542
#   Protenix: TM-scores = ['0.4072', '0.4074', '0.4275', '0.4116', '0.4148'], best = 0.4275
#   Ribonanzanet2: TM-scores = ['0.3961', '0.1346', '0.1162', '0.3922', '0.3937'], best = 0.3961
#   Winner: Protenix (prediction 3) with TM-score = 0.4275
#
# 8YIG_C:
#   DrFold2: TM-scores = ['0.4765', '0.4304', '0.4161', '0.4816', '0.4474'], best = 0.4816
#   Protenix: TM-scores = ['0.6459', '0.6960', '0.6317', '0.6659', '0.6304'], best = 0.6960
#   Ribonanzanet2: TM-scores = ['0.1816', '0.1707', '0.1671', '0.6515', '0.2009'], best = 0.6515
#   Winner: Protenix (prediction 2) with TM-score = 0.6960
#
# 8YIH_C:
#   DrFold2: TM-scores = ['0.3816', '0.4131', '0.3940', '0.4311', '0.4117'], best = 0.4311
#   Protenix: TM-scores = ['0.4595', '0.4351', '0.4487', '0.4827', '0.4712'], best = 0.4827
#   Ribonanzanet2: TM-scores = ['0.5846', '0.1944', '0.6029', '0.5882', '0.5702'], best = 0.6029
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.6029
#
# 8YII_C:
#   DrFold2: TM-scores = ['0.5040', '0.4415', '0.5058', '0.4870', '0.5060'], best = 0.5060
#   Protenix: TM-scores = ['0.4957', '0.4847', '0.4653', '0.5534', '0.4553'], best = 0.5534
#   Ribonanzanet2: TM-scores = ['0.1994', '0.2067', '0.2016', '0.5683', '0.2149'], best = 0.5683
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.5683
#
# 8Z8Q_B:
#   DrFold2: TM-scores = ['0.4856', '0.4289', '0.4711', '0.4896', '0.4757'], best = 0.4896
#   Protenix: TM-scores = ['0.5658', '0.6270', '0.5935', '0.5998', '0.5782'], best = 0.6270
#   Ribonanzanet2: TM-scores = ['0.4870', '0.1609', '0.4751', '0.4745', '0.4869'], best = 0.4870
#   Winner: Protenix (prediction 2) with TM-score = 0.6270
#
# 8Z8U_B:
#   DrFold2: TM-scores = ['0.1590', '0.1512', '0.1796', '0.1838', '0.1996'], best = 0.1996
#   Protenix: TM-scores = ['0.3011', '0.3118', '0.3059', '0.3173', '0.3293'], best = 0.3293
#   Ribonanzanet2: TM-scores = ['0.1177', '0.1106', '0.1098', '0.2937', '0.2924'], best = 0.2937
#   Winner: Protenix (prediction 5) with TM-score = 0.3293
#
# 8Z9K_B:
#   DrFold2: TM-scores = ['0.1871', '0.1458', '0.1714', '0.1371', '0.1706'], best = 0.1871
#   Protenix: TM-scores = ['0.2856', '0.2634', '0.2823', '0.2602', '0.2437'], best = 0.2856
#   Ribonanzanet2: TM-scores = ['0.2331', '0.2478', '0.1547', '0.2445', '0.2483'], best = 0.2483
#   Winner: Protenix (prediction 1) with TM-score = 0.2856
#
# 8ZAU_A:
#   DrFold2: TM-scores = ['0.2628', '0.2223', '0.2992', '0.2630', '0.2809'], best = 0.2992
#   Protenix: TM-scores = ['0.3296', '0.3121', '0.3186', '0.3161', '0.3302'], best = 0.3302
#   Ribonanzanet2: TM-scores = ['0.3048', '0.2729', '0.1358', '0.2580', '0.2877'], best = 0.3048
#   Winner: Protenix (prediction 5) with TM-score = 0.3302
#
# 8ZDR_A:
#   DrFold2: TM-scores = ['0.3205', '0.3120', '0.3366', '0.2975', '0.3012'], best = 0.3366
#   Protenix: TM-scores = ['0.2299', '0.2371', '0.3025', '0.2483', '0.2696'], best = 0.3025
#   Ribonanzanet2: TM-scores = ['0.2751', '0.1475', '0.2736', '0.2732', '0.1727'], best = 0.2751
#   Winner: DrFold2 (prediction 3) with TM-score = 0.3366
#
# 8ZMH_A:
#   DrFold2: TM-scores = ['0.5956', '0.5963', '0.6312', '0.5504', '0.6388'], best = 0.6388
#   Protenix: TM-scores = ['0.2657', '0.2109', '0.2940', '0.2457', '0.2779'], best = 0.2940
#   Ribonanzanet2: TM-scores = ['0.2056', '0.1920', '0.2973', '0.2235', '0.3359'], best = 0.3359
#   Winner: DrFold2 (prediction 5) with TM-score = 0.6388
#
# 8ZQ9_A:
#   DrFold2: TM-scores = ['0.2721', '0.2771', '0.2029', '0.1566', '0.2338'], best = 0.2771
#   Protenix: TM-scores = ['0.2783', '0.2653', '0.2861', '0.2694', '0.3053'], best = 0.3053
#   Ribonanzanet2: TM-scores = ['0.2427', '0.2532', '0.1779', '0.2846', '0.2609'], best = 0.2846
#   Winner: Protenix (prediction 5) with TM-score = 0.3053
#
# 8ZTU_Y:
#   DrFold2: TM-scores = ['0.5252', '0.4830', '0.5297', '0.5320', '0.4953'], best = 0.5320
#   Protenix: TM-scores = ['0.7773', '0.7535', '0.7373', '0.7379', '0.6975'], best = 0.7773
#   Ribonanzanet2: TM-scores = ['0.8092', '0.8012', '0.2414', '0.8051', '0.2348'], best = 0.8092
#   Winner: Ribonanzanet2 (prediction 1) with TM-score = 0.8092
#
# 8ZTV_Y:
#   DrFold2: TM-scores = ['0.5190', '0.4759', '0.5229', '0.5279', '0.4853'], best = 0.5279
#   Protenix: TM-scores = ['0.7112', '0.7143', '0.7028', '0.6865', '0.7011'], best = 0.7143
#   Ribonanzanet2: TM-scores = ['0.2628', '0.8105', '0.8222', '0.8115', '0.7938'], best = 0.8222
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.8222
#
# 9AR4_B:
#   DrFold2: TM-scores = ['0.4286', '0.4071', '0.4044', '0.4413', '0.4263'], best = 0.4413
#   Protenix: TM-scores = ['0.2939', '0.2968', '0.3144', '0.2918', '0.2978'], best = 0.3144
#   Ribonanzanet2: TM-scores = ['0.4197', '0.4026', '0.1460', '0.1691', '0.4085'], best = 0.4197
#   Winner: DrFold2 (prediction 4) with TM-score = 0.4413
#
# 9AR6_B:
#   DrFold2: TM-scores = ['0.4317', '0.4419', '0.4283', '0.4669', '0.3991'], best = 0.4669
#   Protenix: TM-scores = ['0.3132', '0.3332', '0.3070', '0.3281', '0.3036'], best = 0.3332
#   Ribonanzanet2: TM-scores = ['0.4012', '0.1691', '0.1448', '0.4198', '0.4398'], best = 0.4398
#   Winner: DrFold2 (prediction 4) with TM-score = 0.4669
#
# 9AR7_B:
#   DrFold2: TM-scores = ['0.5238', '0.4024', '0.3831', '0.4156', '0.4234'], best = 0.5238
#   Protenix: TM-scores = ['0.3155', '0.3146', '0.3530', '0.3078', '0.2969'], best = 0.3530
#   Ribonanzanet2: TM-scores = ['0.3352', '0.2978', '0.3341', '0.3408', '0.2622'], best = 0.3408
#   Winner: DrFold2 (prediction 1) with TM-score = 0.5238
#
# 9B0Q_AP:
#   DrFold2: TM-scores = ['0.5033', '0.4752', '0.4840', '0.5073', '0.4800'], best = 0.5073
#   Protenix: TM-scores = ['0.7502', '0.7119', '0.7225', '0.6849', '0.7312'], best = 0.7502
#   Ribonanzanet2: TM-scores = ['0.7625', '0.1999', '0.1948', '0.7509', '0.1935'], best = 0.7625
#   Winner: Ribonanzanet2 (prediction 1) with TM-score = 0.7625
#
# 9B0S_Et:
#   DrFold2: TM-scores = ['0.4845', '0.4697', '0.4883', '0.4878', '0.4979'], best = 0.4979
#   Protenix: TM-scores = ['0.6821', '0.6405', '0.6520', '0.6773', '0.6515'], best = 0.6821
#   Ribonanzanet2: TM-scores = ['0.2027', '0.7534', '0.7466', '0.7598', '0.7602'], best = 0.7602
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.7602
#
# 9B1Y_4:
#   DrFold2: TM-scores = ['0.3230', '0.3261', '0.3856', '0.2209', '0.2379'], best = 0.3856
#   Protenix: TM-scores = ['0.4869', '0.5108', '0.4924', '0.5314', '0.5037'], best = 0.5314
#   Ribonanzanet2: TM-scores = ['0.2616', '0.2396', '0.1620', '0.1253', '0.1427'], best = 0.2616
#   Winner: Protenix (prediction 4) with TM-score = 0.5314
#
# 9B2K_B:
#   DrFold2: TM-scores = ['0.2181', '0.2243', '0.2360', '0.2547', '0.2323'], best = 0.2547
#   Protenix: TM-scores = ['0.2420', '0.2522', '0.2447', '0.2540', '0.2466'], best = 0.2540
#   Ribonanzanet2: TM-scores = ['0.1784', '0.1693', '0.4070', '0.1545', '0.3727'], best = 0.4070
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.4070
#
# 9B83_C:
#   DrFold2: TM-scores = ['0.1746', '0.1560', '0.1839', '0.1628', '0.1788'], best = 0.1839
#   Protenix: TM-scores = ['0.2912', '0.2805', '0.2354', '0.2657', '0.2960'], best = 0.2960
#   Ribonanzanet2: TM-scores = ['0.2027', '0.1073', '0.1710', '0.1103', '0.1333'], best = 0.2027
#   Winner: Protenix (prediction 5) with TM-score = 0.2960
#
# 9B84_F:
#   DrFold2: TM-scores = ['0.4552', '0.4317', '0.4167', '0.3919', '0.4174'], best = 0.4552
#   Protenix: TM-scores = ['0.6092', '0.4991', '0.5323', '0.5220', '0.5649'], best = 0.6092
#   Ribonanzanet2: TM-scores = ['0.1410', '0.1404', '0.1504', '0.1440', '0.1473'], best = 0.1504
#   Winner: Protenix (prediction 1) with TM-score = 0.6092
#
# 9B89_C:
#   DrFold2: TM-scores = ['0.2482', '0.2427', '0.2525', '0.2419', '0.2140'], best = 0.2525
#   Protenix: TM-scores = ['0.3902', '0.3748', '0.3742', '0.3806', '0.3870'], best = 0.3902
#   Ribonanzanet2: TM-scores = ['0.1106', '0.3395', '0.0972', '0.1051', '0.0975'], best = 0.3395
#   Winner: Protenix (prediction 1) with TM-score = 0.3902
#
# 9C8K_2:
#   DrFold2: TM-scores = ['0.1301', '0.1625', '0.1164', '0.1414', '0.1424'], best = 0.1625
#   Protenix: TM-scores = ['0.1937', '0.2027', '0.2478', '0.2247', '0.1922'], best = 0.2478
#   Ribonanzanet2: TM-scores = ['0.1274', '0.1283', '0.1435', '0.1466', '0.1168'], best = 0.1466
#   Winner: Protenix (prediction 3) with TM-score = 0.2478
#
# 9DCF_C:
#   DrFold2: TM-scores = ['0.3361', '0.3281', '0.3457', '0.3545', '0.3552'], best = 0.3552
#   Protenix: TM-scores = ['0.4577', '0.5187', '0.4070', '0.5039', '0.4820'], best = 0.5187
#   Ribonanzanet2: TM-scores = ['0.1430', '0.1555', '0.1694', '0.4468', '0.1445'], best = 0.4468
#   Winner: Protenix (prediction 2) with TM-score = 0.5187
#
# 9DE5_C:
#   DrFold2: TM-scores = ['0.3396', '0.3189', '0.3310', '0.3273', '0.2707'], best = 0.3396
#   Protenix: TM-scores = ['0.4368', '0.4615', '0.4470', '0.4626', '0.4865'], best = 0.4865
#   Ribonanzanet2: TM-scores = ['0.1391', '0.1357', '0.4760', '0.1310', '0.1377'], best = 0.4760
#   Winner: Protenix (prediction 5) with TM-score = 0.4865
#
# 9DE5_D:
#   DrFold2: TM-scores = ['0.3270', '0.3013', '0.3183', '0.3131', '0.2864'], best = 0.3270
#   Protenix: TM-scores = ['0.5336', '0.5394', '0.4829', '0.5111', '0.5159'], best = 0.5394
#   Ribonanzanet2: TM-scores = ['0.4940', '0.1603', '0.1321', '0.1588', '0.1434'], best = 0.4940
#   Winner: Protenix (prediction 2) with TM-score = 0.5394
#
# 9DE6_A:
#   DrFold2: TM-scores = ['0.3113', '0.2945', '0.3324', '0.3074', '0.2551'], best = 0.3324
#   Protenix: TM-scores = ['0.4568', '0.4767', '0.4931', '0.4785', '0.4979'], best = 0.4979
#   Ribonanzanet2: TM-scores = ['0.1384', '0.1409', '0.4719', '0.1422', '0.4727'], best = 0.4727
#   Winner: Protenix (prediction 5) with TM-score = 0.4979
#
# 9DE6_B:
#   DrFold2: TM-scores = ['0.3377', '0.3443', '0.3522', '0.3453', '0.3180'], best = 0.3522
#   Protenix: TM-scores = ['0.5335', '0.5036', '0.5170', '0.5352', '0.5124'], best = 0.5352
#   Ribonanzanet2: TM-scores = ['0.4842', '0.1517', '0.1577', '0.4699', '0.4899'], best = 0.4899
#   Winner: Protenix (prediction 4) with TM-score = 0.5352
#
# 9DE7_A:
#   DrFold2: TM-scores = ['0.4020', '0.3575', '0.3639', '0.3725', '0.2586'], best = 0.4020
#   Protenix: TM-scores = ['0.5244', '0.5015', '0.5750', '0.5696', '0.5559'], best = 0.5750
#   Ribonanzanet2: TM-scores = ['0.4675', '0.4496', '0.4674', '0.4828', '0.1562'], best = 0.4828
#   Winner: Protenix (prediction 3) with TM-score = 0.5750
#
# 9DE8_A:
#   DrFold2: TM-scores = ['0.3741', '0.3408', '0.3721', '0.3502', '0.2860'], best = 0.3741
#   Protenix: TM-scores = ['0.4580', '0.5140', '0.5227', '0.4566', '0.5039'], best = 0.5227
#   Ribonanzanet2: TM-scores = ['0.1618', '0.1570', '0.1527', '0.1555', '0.4506'], best = 0.4506
#   Winner: Protenix (prediction 3) with TM-score = 0.5227
#
# 9DPA_C:
#   DrFold2: TM-scores = ['0.4646', '0.4441', '0.4765', '0.4672', '0.4668'], best = 0.4765
#   Protenix: TM-scores = ['0.6866', '0.6969', '0.6823', '0.6121', '0.6533'], best = 0.6969
#   Ribonanzanet2: TM-scores = ['0.4324', '0.1825', '0.1887', '0.1688', '0.4255'], best = 0.4324
#   Winner: Protenix (prediction 2) with TM-score = 0.6969
#
# 9DPB_C:
#   DrFold2: TM-scores = ['0.5125', '0.5047', '0.5041', '0.5155', '0.5061'], best = 0.5155
#   Protenix: TM-scores = ['0.8071', '0.7969', '0.8136', '0.8007', '0.7857'], best = 0.8136
#   Ribonanzanet2: TM-scores = ['0.1909', '0.1897', '0.4414', '0.1940', '0.1910'], best = 0.4414
#   Winner: Protenix (prediction 3) with TM-score = 0.8136
#
# 9DPL_C:
#   DrFold2: TM-scores = ['0.3752', '0.3592', '0.3814', '0.3848', '0.3795'], best = 0.3848
#   Protenix: TM-scores = ['0.5983', '0.6540', '0.6139', '0.6112', '0.6637'], best = 0.6637
#   Ribonanzanet2: TM-scores = ['0.3729', '0.3700', '0.3696', '0.1368', '0.3729'], best = 0.3729
#   Winner: Protenix (prediction 5) with TM-score = 0.6637
#
# 9DRS_C:
#   DrFold2: TM-scores = ['0.4833', '0.4531', '0.4625', '0.5012', '0.4621'], best = 0.5012
#   Protenix: TM-scores = ['0.5757', '0.5665', '0.6313', '0.6211', '0.5849'], best = 0.6313
#   Ribonanzanet2: TM-scores = ['0.8471', '0.1995', '0.2069', '0.8304', '0.8476'], best = 0.8476
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.8476
#
# 9E2W_F:
#   DrFold2: TM-scores = ['0.2146', '0.2021', '0.2049', '0.2269', '0.1602'], best = 0.2269
#   Protenix: TM-scores = ['0.1573', '0.1614', '0.1805', '0.1684', '0.1691'], best = 0.1805
#   Ribonanzanet2: TM-scores = ['0.0900', '0.0930', '0.0894', '0.1086', '0.1142'], best = 0.1142
#   Winner: DrFold2 (prediction 4) with TM-score = 0.2269
#
# 9E2Y_F:
#   DrFold2: TM-scores = ['0.1785', '0.1715', '0.1231', '0.1267', '0.1350'], best = 0.1785
#   Protenix: TM-scores = ['0.2428', '0.2437', '0.1774', '0.2434', '0.2441'], best = 0.2441
#   Ribonanzanet2: TM-scores = ['0.1471', '0.1466', '0.1693', '0.1626', '0.1443'], best = 0.1693
#   Winner: Protenix (prediction 5) with TM-score = 0.2441
#
# 9E2Z_F:
#   DrFold2: TM-scores = ['0.1527', '0.1538', '0.1200', '0.1322', '0.1261'], best = 0.1538
#   Protenix: TM-scores = ['0.2264', '0.1713', '0.2543', '0.2242', '0.1411'], best = 0.2543
#   Ribonanzanet2: TM-scores = ['0.1564', '0.1723', '0.1556', '0.1175', '0.1536'], best = 0.1723
#   Winner: Protenix (prediction 3) with TM-score = 0.2543
#
# 9FCV_B:
#   DrFold2: TM-scores = ['0.1966', '0.2412', '0.2227', '0.1637', '0.2130'], best = 0.2412
#   Protenix: TM-scores = ['0.2598', '0.2351', '0.2239', '0.2413', '0.2236'], best = 0.2598
#   Ribonanzanet2: TM-scores = ['0.3815', '0.4531', '0.4368', '0.1100', '0.1064'], best = 0.4531
#   Winner: Ribonanzanet2 (prediction 2) with TM-score = 0.4531
#
# 9FIB_Y:
#   DrFold2: TM-scores = ['0.0716', '0.1143', '0.1119', '0.1228', '0.1018'], best = 0.1228
#   Protenix: TM-scores = ['0.0731', '0.0708', '0.0440', '0.0735', '0.0776'], best = 0.0776
#   Ribonanzanet2: TM-scores = ['0.1304', '0.0899', '0.0920', '0.0923', '0.0949'], best = 0.1304
#   Winner: Ribonanzanet2 (prediction 1) with TM-score = 0.1304
#
# 9FN3_B:
#   DrFold2: TM-scores = ['0.1940', '0.1958', '0.1967', '0.2044', '0.2012'], best = 0.2044
#   Protenix: TM-scores = ['0.2780', '0.2756', '0.2988', '0.2938', '0.3066'], best = 0.3066
#   Ribonanzanet2: TM-scores = ['0.2521', '0.1379', '0.1694', '0.1344', '0.1244'], best = 0.2521
#   Winner: Protenix (prediction 5) with TM-score = 0.3066
#
# 9G06_a:
#   DrFold2: TM-scores = ['0.4226', '0.4368', '0.4441', '0.4545', '0.4304'], best = 0.4545
#   Protenix: TM-scores = ['0.6976', '0.6668', '0.6698', '0.6753', '0.6654'], best = 0.6976
#   Ribonanzanet2: TM-scores = ['0.6050', '0.5952', '0.1787', '0.6100', '0.6205'], best = 0.6205
#   Winner: Protenix (prediction 1) with TM-score = 0.6976
#
# 9GBW_R:
#   DrFold2: TM-scores = ['0.1950', '0.2375', '0.2065', '0.1761', '0.2391'], best = 0.2391
#   Protenix: TM-scores = ['0.2477', '0.2011', '0.2133', '0.2072', '0.2356'], best = 0.2477
#   Ribonanzanet2: TM-scores = ['0.2852', '0.1302', '0.2799', '0.3033', '0.1276'], best = 0.3033
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.3033
#
# 9GBZ_R:
#   DrFold2: TM-scores = ['0.2369', '0.2444', '0.2036', '0.1821', '0.2192'], best = 0.2444
#   Protenix: TM-scores = ['0.2956', '0.2539', '0.3233', '0.3112', '0.2980'], best = 0.3233
#   Ribonanzanet2: TM-scores = ['0.1203', '0.1536', '0.3790', '0.3459', '0.3700'], best = 0.3790
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.3790
#
# 9GC0_Q:
#   DrFold2: TM-scores = ['0.1741', '0.1829', '0.1640', '0.2276', '0.2162'], best = 0.2276
#   Protenix: TM-scores = ['0.2587', '0.2790', '0.3310', '0.3192', '0.2894'], best = 0.3310
#   Ribonanzanet2: TM-scores = ['0.1109', '0.1136', '0.2628', '0.2010', '0.1115'], best = 0.2628
#   Winner: Protenix (prediction 3) with TM-score = 0.3310
#
# 9GCL_A:
#   DrFold2: TM-scores = ['0.1534', '0.2096', '0.1768', '0.1824', '0.1149'], best = 0.2096
#   Protenix: TM-scores = ['0.2546', '0.2313', '0.2701', '0.2575', '0.2657'], best = 0.2701
#   Ribonanzanet2: TM-scores = ['0.2315', '0.2531', '0.2273', '0.2425', '0.1991'], best = 0.2531
#   Winner: Protenix (prediction 3) with TM-score = 0.2701
#
# 9GCM_A:
#   DrFold2: TM-scores = ['0.2543', '0.2344', '0.2175', '0.2417', '0.1955'], best = 0.2543
#   Protenix: TM-scores = ['0.2927', '0.3016', '0.3111', '0.2702', '0.3263'], best = 0.3263
#   Ribonanzanet2: TM-scores = ['0.3489', '0.4087', '0.1172', '0.1294', '0.3457'], best = 0.4087
#   Winner: Ribonanzanet2 (prediction 2) with TM-score = 0.4087
#
# 9GFT_A3:
#   DrFold2: TM-scores = ['0.4827', '0.4735', '0.5121', '0.4823', '0.4817'], best = 0.5121
#   Protenix: TM-scores = ['0.6684', '0.6201', '0.5934', '0.6172', '0.6671'], best = 0.6684
#   Ribonanzanet2: TM-scores = ['0.1963', '0.1818', '0.1896', '0.4781', '0.1690'], best = 0.4781
#   Winner: Protenix (prediction 1) with TM-score = 0.6684
#
# 9GFT_AU:
#   DrFold2: TM-scores = ['0.4568', '0.4365', '0.4714', '0.4627', '0.4505'], best = 0.4714
#   Protenix: TM-scores = ['0.7272', '0.7098', '0.7338', '0.7212', '0.7195'], best = 0.7338
#   Ribonanzanet2: TM-scores = ['0.1968', '0.5920', '0.5832', '0.2125', '0.2249'], best = 0.5920
#   Winner: Protenix (prediction 3) with TM-score = 0.7338
#
# 9GHF_Z:
#   DrFold2: TM-scores = ['0.5551', '0.5315', '0.5574', '0.5708', '0.5589'], best = 0.5708
#   Protenix: TM-scores = ['0.7877', '0.7481', '0.6906', '0.7473', '0.7392'], best = 0.7877
#   Ribonanzanet2: TM-scores = ['0.2507', '0.2417', '0.9072', '0.9023', '0.9117'], best = 0.9117
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.9117
#
# 9HNY_CA:
#   DrFold2: TM-scores = ['0.1044', '0.0967', '0.0828', '0.1224', '0.1215'], best = 0.1224
#   Protenix: TM-scores = ['0.1889', '0.1788', '0.1899', '0.1759', '0.1806'], best = 0.1899
#   Ribonanzanet2: TM-scores = ['0.2033', '0.2303', '0.3510', '0.3327', '0.3349'], best = 0.3510
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.3510
#
# 9IS7_B:
#   DrFold2: TM-scores = ['0.1722', '0.1397', '0.1442', '0.1640', '0.2009'], best = 0.2009
#   Protenix: TM-scores = ['0.2560', '0.2275', '0.2355', '0.2157', '0.1730'], best = 0.2560
#   Ribonanzanet2: TM-scores = ['0.1804', '0.1588', '0.1855', '0.1797', '0.1798'], best = 0.1855
#   Winner: Protenix (prediction 1) with TM-score = 0.2560
#
# 9ISV_A:
#   DrFold2: TM-scores = ['0.2004', '0.1489', '0.1635', '0.2168', '0.1713'], best = 0.2168
#   Protenix: TM-scores = ['0.2238', '0.1862', '0.2483', '0.1909', '0.1871'], best = 0.2483
#   Ribonanzanet2: TM-scores = ['0.1648', '0.1560', '0.1781', '0.1573', '0.1877'], best = 0.1877
#   Winner: Protenix (prediction 3) with TM-score = 0.2483
#
# 9J3R_B:
#   DrFold2: TM-scores = ['0.1390', '0.1473', '0.1594', '0.1505', '0.1640'], best = 0.1640
#   Protenix: TM-scores = ['0.1964', '0.2177', '0.1673', '0.1741', '0.1747'], best = 0.2177
#   Ribonanzanet2: TM-scores = ['0.1347', '0.1652', '0.1562', '0.1502', '0.1673'], best = 0.1673
#   Winner: Protenix (prediction 2) with TM-score = 0.2177
#
# 9J3T_B:
#   DrFold2: TM-scores = ['0.1384', '0.1349', '0.1261', '0.1383', '0.1584'], best = 0.1584
#   Protenix: TM-scores = ['0.1418', '0.1602', '0.2074', '0.1731', '0.1644'], best = 0.2074
#   Ribonanzanet2: TM-scores = ['0.1882', '0.2007', '0.1444', '0.1505', '0.1490'], best = 0.2007
#   Winner: Protenix (prediction 3) with TM-score = 0.2074
#
# 9J6Y_E:
#   DrFold2: TM-scores = ['0.1595', '0.1358', '0.1852', '0.1518', '0.1810'], best = 0.1852
#   Protenix: TM-scores = ['0.1680', '0.1753', '0.1464', '0.2002', '0.1873'], best = 0.2002
#   Ribonanzanet2: TM-scores = ['0.1619', '0.1484', '0.1579', '0.1469', '0.1652'], best = 0.1652
#   Winner: Protenix (prediction 4) with TM-score = 0.2002
#
# 9KPO_B:
#   DrFold2: TM-scores = ['0.1337', '0.1967', '0.1509', '0.2483', '0.2141'], best = 0.2483
#   Protenix: TM-scores = ['0.1953', '0.2282', '0.2448', '0.1772', '0.2061'], best = 0.2448
#   Ribonanzanet2: TM-scores = ['0.1583', '0.1671', '0.1780', '0.1629', '0.1833'], best = 0.1833
#   Winner: DrFold2 (prediction 4) with TM-score = 0.2483
#
# 9L0R_K:
#   DrFold2: TM-scores = ['0.1408', '0.1049', '0.1337', '0.1371', '0.1071'], best = 0.1408
#   Protenix: TM-scores = ['0.2011', '0.1805', '0.1877', '0.1920', '0.1967'], best = 0.2011
#   Ribonanzanet2: TM-scores = ['0.1359', '0.1894', '0.1524', '0.1582', '0.1505'], best = 0.1894
#   Winner: Protenix (prediction 1) with TM-score = 0.2011
#
# 9L5R_2:
#   DrFold2: TM-scores = ['0.2186', '0.1818', '0.1563', '0.1786', '0.1782'], best = 0.2186
#   Protenix: TM-scores = ['0.2269', '0.2071', '0.2045', '0.2242', '0.1843'], best = 0.2269
#   Ribonanzanet2: TM-scores = ['0.2122', '0.1430', '0.1897', '0.1794', '0.1984'], best = 0.2122
#   Winner: Protenix (prediction 1) with TM-score = 0.2269
#
# 9L5R_6:
#   DrFold2: TM-scores = ['0.2591', '0.1711', '0.2703', '0.1851', '0.1834'], best = 0.2703
#   Protenix: TM-scores = ['0.1527', '0.1588', '0.1749', '0.1620', '0.1713'], best = 0.1749
#   Ribonanzanet2: TM-scores = ['0.1767', '0.1843', '0.1802', '0.4911', '0.1915'], best = 0.4911
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.4911
#
# 9L5S_5:
#   DrFold2: TM-scores = ['0.3164', '0.3252', '0.3390', '0.3050', '0.2904'], best = 0.3390
#   Protenix: TM-scores = ['0.3246', '0.3330', '0.3587', '0.3167', '0.2467'], best = 0.3587
#   Ribonanzanet2: TM-scores = ['0.1465', '0.1729', '0.3496', '0.3908', '0.2005'], best = 0.3908
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.3908
#
# 9L5S_6:
#   DrFold2: TM-scores = ['0.2417', '0.1294', '0.2650', '0.2121', '0.1932'], best = 0.2650
#   Protenix: TM-scores = ['0.1626', '0.2281', '0.1586', '0.1678', '0.1742'], best = 0.2281
#   Ribonanzanet2: TM-scores = ['0.1753', '0.1852', '0.1826', '0.5299', '0.5299'], best = 0.5299
#   Winner: Ribonanzanet2 (prediction 5) with TM-score = 0.5299
#
# 9L5T_6:
#   DrFold2: TM-scores = ['0.2426', '0.1810', '0.2619', '0.1942', '0.1867'], best = 0.2619
#   Protenix: TM-scores = ['0.1747', '0.1737', '0.1497', '0.1651', '0.2182'], best = 0.2182
#   Ribonanzanet2: TM-scores = ['0.1892', '0.5152', '0.5278', '0.2079', '0.2009'], best = 0.5278
#   Winner: Ribonanzanet2 (prediction 3) with TM-score = 0.5278
#
# 9LCR_B:
#   DrFold2: TM-scores = ['0.2657', '0.2249', '0.2195', '0.2574', '0.2603'], best = 0.2657
#   Protenix: TM-scores = ['0.3180', '0.2930', '0.3293', '0.2542', '0.3750'], best = 0.3750
#   Ribonanzanet2: TM-scores = ['0.1724', '0.1768', '0.1838', '0.2322', '0.1669'], best = 0.2322
#   Winner: Protenix (prediction 5) with TM-score = 0.3750
#
# 9LMF_F:
#   DrFold2: TM-scores = ['0.2074', '0.1749', '0.2083', '0.1880', '0.2040'], best = 0.2083
#   Protenix: TM-scores = ['0.2403', '0.1994', '0.2062', '0.3234', '0.1968'], best = 0.3234
#   Ribonanzanet2: TM-scores = ['0.2105', '0.2022', '0.2018', '0.2090', '0.1752'], best = 0.2105
#   Winner: Protenix (prediction 4) with TM-score = 0.3234
#
# 9MTY_C:
#   DrFold2: TM-scores = ['0.1391', '0.1325', '0.1305', '0.1676', '0.1691'], best = 0.1691
#   Protenix: TM-scores = ['0.1597', '0.1726', '0.1626', '0.1643', '0.1686'], best = 0.1726
#   Ribonanzanet2: TM-scores = ['0.1357', '0.1324', '0.1321', '0.1306', '0.1308'], best = 0.1357
#   Winner: Protenix (prediction 2) with TM-score = 0.1726
#
# 9N2B_5:
#   DrFold2: TM-scores = ['0.7225', '0.7248', '0.7213', '0.7307', '0.7358'], best = 0.7358
#   Protenix: TM-scores = ['0.6854', '0.4069', '0.6520', '0.8162', '0.7654'], best = 0.8162
#   Ribonanzanet2: TM-scores = ['0.9024', '0.2402', '0.9116', '0.9222', '0.8347'], best = 0.9222
#   Winner: Ribonanzanet2 (prediction 4) with TM-score = 0.9222
#
# 9N2C_Pt:
#   DrFold2: TM-scores = ['0.5606', '0.5212', '0.5696', '0.5790', '0.5575'], best = 0.5790
#   Protenix: TM-scores = ['0.7452', '0.7078', '0.7559', '0.7544', '0.7462'], best = 0.7559
#   Ribonanzanet2: TM-scores = ['0.8675', '0.2175', '0.8457', '0.8337', '0.8462'], best = 0.8675
#   Winner: Ribonanzanet2 (prediction 1) with TM-score = 0.8675
#
# Overall Mean TM-score: 0.4792
# Results saved to best_predictions_comparison.csv
# Final mean TM-score across all best predictions: 0.4792

# %%
# Final save to ensure consistency
results_df.to_csv("/kaggle/working/model_selection_df.csv", index=False)
print("Final submission saved to /kaggle/working/")
# Out:
# Final submission saved to /kaggle/working/

# %%
# Confidence statistics

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

drfold2_df = pd.read_csv("/kaggle/input/predictions/drfold2_submission_with_confidence.csv")  # Replace with actual paths
protenix_df = pd.read_csv("/kaggle/input/predictions/protenix_submission_with_confidence.csv")  # Replace with actual paths  
ribonanza_df = pd.read_csv("/kaggle/input/predictions/ribonanzanet2_submission_with_confidence.csv")  # Replace with actual paths

def compute_average(df):
    confidence_cols = ['confidence_1', 'confidence_2', 'confidence_3', 'confidence_4', 'confidence_5']
    
    df_normalized = df.copy()
    
    all_confidence_values = df[confidence_cols].values.flatten()
    global_min = np.min(all_confidence_values)
    global_max = np.max(all_confidence_values)
    
    for col in confidence_cols:
        df_normalized[col] = (df[col] - global_min) / (global_max - global_min)
    
    for col in confidence_cols:
        print(f"  {col}: [{df[col].min():.4f}, {df[col].max():.4f}]")
    
    for col in confidence_cols:
        print(f"  {col}: [{df_normalized[col].min():.4f}, {df_normalized[col].max():.4f}]")
    
    df_normalized['avg_confidence_per_residue'] = df_normalized[confidence_cols].mean(axis=1)
    
    avg_confidence_per_sequence = df_normalized.groupby('target_id')['avg_confidence_per_residue'].mean()
    
    overall_avg_confidence = avg_confidence_per_sequence.mean()
    
    print(f"Overall average confidence score (normalized): {overall_avg_confidence:.4f}")

compute_average(drfold2_df)
compute_average(protenix_df)
compute_average(ribonanza_df)
# Out:
#   confidence_1: [0.0303, 0.0752]
#   confidence_2: [0.0330, 0.0755]
#   confidence_3: [0.0384, 0.0746]
#   confidence_4: [0.0324, 0.0741]
#   confidence_5: [0.0336, 0.0775]
#   confidence_1: [0.0000, 0.9512]
#   confidence_2: [0.0579, 0.9569]
#   confidence_3: [0.1707, 0.9374]
#   confidence_4: [0.0444, 0.9274]
#   confidence_5: [0.0695, 1.0000]
# Overall average confidence score (normalized): 0.5150
#   confidence_1: [-6.3415, 1.0973]
#   confidence_2: [-6.3525, 1.0678]
#   confidence_3: [-6.3451, 1.0904]
#   confidence_4: [-6.4334, 1.0702]
#   confidence_5: [-6.3419, 1.0601]
#   confidence_1: [0.0122, 1.0000]
#   confidence_2: [0.0107, 0.9961]
#   confidence_3: [0.0117, 0.9991]
#   confidence_4: [0.0000, 0.9964]
#   confidence_5: [0.0121, 0.9951]
# Overall average confidence score (normalized): 0.5881
#   confidence_1: [0.0222, 0.0551]
#   confidence_2: [0.0242, 0.0553]
#   confidence_3: [0.0281, 0.0546]
#   confidence_4: [0.0229, 0.0543]
#   confidence_5: [0.0245, 0.0571]
#   confidence_1: [0.0000, 0.9414]
#   confidence_2: [0.0567, 0.9470]
#   confidence_3: [0.1693, 0.9285]
#   confidence_4: [0.0219, 0.9193]
#   confidence_5: [0.0678, 1.0000]
# Overall average confidence score (normalized): 0.5080
